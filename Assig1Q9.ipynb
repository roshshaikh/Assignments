# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Q9_df=pd.read_csv("D:\\DS DATA\\Q9.csv")
Q9_df.head()
# Out:
#    Index  speed  dist
# 0      1      4     2
# 1      2      4    10
# 2      3      7     4
# 3      4      7    22
# 4      5      8    16

# %%
Q9_df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
Q9_df.skew()
# Out:
# Index    0.000000
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
Q9_df.kurt()
# Out:
# Index   -1.200000
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
f,ax=plt.subplots(figsize=(15,5))
plt.subplot(1,3,1)
plt.boxplot(Q9.Points)
plt.title('Points')
plt.subplot(1,3,2)
plt.boxplot(Q9.Score)
plt.title('Score')
plt.subplot(1,3,3)
plt.boxplot(Q9.Weigh)
plt.title('Weigh')
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_8280\4248378706.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 f,ax=plt.subplots(figsize=(15,5))
#       2 plt.subplot(1,3,1)
# ----> 3 plt.boxplot(Q9.Points)
#       4 plt.title('Points')
#       5 plt.subplot(1,3,2)
#
# NameError: name 'Q9' is not defined
